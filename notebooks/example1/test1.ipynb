# %% [markdown]
# # Testing code from source:
# https://github.com/TithiSreemany/Snapchat-Filter-using-OpenCV/blob/main/Images/Hermione1.jpg
#
# Do not work...

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
eye_cascade = cv2.CascadeClassifier("frontalEyes35x16.xml")

# %%
img = plt.imread("hh.jpeg")
plt.imshow(img)

# %%
img.shape
# Out:
# (487, 586, 3)

# %%
img_c = img.copy()

# %%
eye=eye_cascade.detectMultiScale(img)[0]
print (eye)
# Out:
# [220 130 135  62]

# %%
eye_x,eye_y,eye_w, eye_h= eye
img = cv2.rectangle(img, (eye_x, eye_y), (eye_x + eye_w, eye_y + eye_h), (255,255,255), 5 )
plt.imshow(img)

# %%
glasses=plt.imread("glasses.png")
glasses.shape
# Out:
# (200, 200, 4)

# %%
for i in range(glasses.shape[0]):
  for j in range(glasses.shape[1]):
    if (glasses[i,j,3]>0):
      img_c[eye_y+i-20,eye_x+j-23, :]=glasses[i,j,:-1]

# %%
plt.imshow(img_c)
